# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df = df.drop('Cabin',axis = 1)

# %%
df['Age'].fillna(df['Age'].mean(),inplace = True)
df['Embarked'].fillna(df['Embarked'].mode()[0],inplace = True)
# Out:
# /tmp/ipykernel_1218/3986452865.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace = True)
# /tmp/ipykernel_1218/3986452865.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna(df['Embarked'].mode()[0],inplace = True)

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Embarked'] = le.fit_transform(df['Embarked'])
df['Ticket'] = le.fit_transform(df['Ticket'])
df['Sex'] = le.fit_transform(df['Sex'])

# %%
from scipy.stats import zscore
z = zscore(df['Fare'])
zz = zscore(df['Age'])
zzz = zscore(df['Parch'])
df[(np.abs(z)>3) | (np.abs(zz)>3) | (np.abs(zzz)>3)]
# Out:
#      PassengerId  Survived  Pclass  \
# 13            14         0       3
# 25            26         1       3
# 27            28         0       1
# 86            87         0       3
# 88            89         1       1
# 96            97         0       1
# 116          117         0       3
# 118          119         0       1
# 167          168         0       3
# 258          259         1       1
# 299          300         1       1
# 311          312         1       1
# 341          342         1       1
# 360          361         0       3
# 377          378         0       1
# 380          381         1       1
# 437          438         1       2
# 438          439         0       1
# 493          494         0       1
# 527          528         0       1
# 557          558         0       1
# 567          568         0       3
# 610          611         0       3
# 630          631         1       1
# 638          639         0       3
# 672          673         0       2
# 678          679         0       3
# 679          680         1       1
# 689          690         1       1
# 700          701         1       1
# 716          717         1       1
# 730          731         1       1
# 736          737         0       3
# 737          738         1       1
# 742          743         1       1
# 745          746         0       1
# 774          775         1       2
# 779          780         1       1
# 851          852         0       3
# 858          859         1       3
# 885          886         0       3
#
#                                                   Name  Sex        Age  SibSp  \
# 13                         Andersson, Mr. Anders Johan    1  39.000000      1
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...    0  38.000000      1
# 27                      Fortune, Mr. Charles Alexander    1  19.000000      3
# 86                              Ford, Mr. William Neal    1  16.000000      1
# 88                          Fortune, Miss. Mabel Helen    0  23.000000      3
# 96                           Goldschmidt, Mr. George B    1  71.000000      0
# 116                               Connors, Mr. Patrick    1  70.500000      0
# 118                           Baxter, Mr. Quigg Edmond    1  24.000000      0
# 167    Skoog, Mrs. William (Anna Bernhardina Karlsson)    0  45.000000      1
# 258                                   Ward, Miss. Anna    0  35.000000      0
# 299    Baxter, Mrs. James (Helene DeLaudeniere Chaput)    0  50.000000      0
# 311                         Ryerson, Miss. Emily Borie    0  18.000000      2
# 341                     Fortune, Miss. Alice Elizabeth    0  24.000000      3
# 360                                 Skoog, Mr. Wilhelm    1  40.000000      1
# 377                          Widener, Mr. Harry Elkins    1  27.000000      0
# 380                              Bidois, Miss. Rosalie    0  42.000000      0
# 437              Richards, Mrs. Sidney (Emily Hocking)    0  24.000000      2
# 438                                  Fortune, Mr. Mark    1  64.000000      1
# 493                            Artagaveytia, Mr. Ramon    1  71.000000      0
# 527                                 Farthing, Mr. John    1  29.699118      0
# 557                                Robbins, Mr. Victor    1  29.699118      0
# 567        Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.000000      0
# 610  Andersson, Mrs. Anders Johan (Alfrida Konstant...    0  39.000000      1
# 630               Barkworth, Mr. Algernon Henry Wilson    1  80.000000      0
# 638             Panula, Mrs. Juha (Maria Emilia Ojala)    0  41.000000      0
# 672                        Mitchell, Mr. Henry Michael    1  70.000000      0
# 678            Goodwin, Mrs. Frederick (Augusta Tyler)    0  43.000000      1
# 679                 Cardeza, Mr. Thomas Drake Martinez    1  36.000000      0
# 689                  Madill, Miss. Georgette Alexandra    0  15.000000      0
# 700  Astor, Mrs. John Jacob (Madeleine Talmadge Force)    0  18.000000      1
# 716                      Endres, Miss. Caroline Louise    0  38.000000      0
# 730                      Allen, Miss. Elisabeth Walton    0  29.000000      0
# 736            Ford, Mrs. Edward (Margaret Ann Watson)    0  48.000000      1
# 737                             Lesurer, Mr. Gustave J    1  35.000000      0
# 742              Ryerson, Miss. Susan Parker "Suzette"    0  21.000000      2
# 745                       Crosby, Capt. Edward Gifford    1  70.000000      1
# 774              Hocking, Mrs. Elizabeth (Eliza Needs)    0  54.000000      1
# 779  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...    0  43.000000      0
# 851                                Svensson, Mr. Johan    1  74.000000      0
# 858              Baclini, Mrs. Solomon (Latifa Qurban)    0  24.000000      0
# 885               Rice, Mrs. William (Margaret Norton)    0  39.000000      0
#
#      Parch  Ticket      Fare  Embarked
# 13       5     333   31.2750         2
# 25       5     329   31.3875         2
# 27       2      95  263.0000         2
# 86       3     676   34.3750         2
# 88       2      95  263.0000         2
# 96       0     607   34.6542         0
# 116      0     460    7.7500         1
# 118      1     585  247.5208         0
# 167      4     337   27.9000         2
# 258      0     608  512.3292         0
# 299      1     585  247.5208         0
# 311      2     602  262.3750         0
# 341      2      95  263.0000         2
# 360      4     337   27.9000         2
# 377      2      27  211.5000         0
# 380      0     610  227.5250         0
# 437      3     237   18.7500         2
# 438      4      95  263.0000         2
# 493      0     603   49.5042         0
# 527      0     583  221.7792         2
# 557      0     610  227.5250         0
# 567      4     395   21.0750         2
# 610      5     333   31.2750         2
# 630      0     218   30.0000         2
# 638      5     249   39.6875         2
# 672      0     550   10.5000         2
# 678      6     566   46.9000         2
# 679      1     608  512.3292         0
# 689      1     141  211.3375         2
# 700      0     610  227.5250         0
# 716      0     610  227.5250         0
# 730      0     141  211.3375         2
# 736      3     676   34.3750         2
# 737      0     608  512.3292         0
# 742      2     602  262.3750         0
# 745      1     680   71.0000         2
# 774      3     236   23.0000         2
# 779      1     141  211.3375         2
# 851      0     317    7.7750         2
# 858      3     194   19.2583         0
# 885      5     480   29.1250         1

# %%
from scipy.stats.mstats import winsorize
df['Age'] = winsorize(df['Age'],limits = [0,0.1])
df['Fare'] = winsorize(df['Fare'],limits = [0,0.1])

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
from scipy.stats import zscore
z = zscore(df['Age'])
df[np.abs(z)>3]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []

# %%
x = df.drop(['Name','Survived'],axis = 1)
y = df['Survived']

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

model = KNeighborsClassifier(n_neighbors = 10)
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

print("Acuuracy = ",accuracy_score(y_test,y_pred))
# Out:
# Acuuracy =  0.659217877094972
